# %% [markdown]
# <a href="https://colab.research.google.com/github/taufique97alam-arch/python_codes/blob/main/Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
a=input("enter your name:-")
# Out:
# hello world
# enter your name:-taufique alam

# %%
print("the name entered is",a,type(a))
# Out:
# the name entered is taufique alam <class 'str'>

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
#welcome to python ths is comment
print("welcome taufique")
# Out:
# welcome taufique

# %%
"""
this
is comment"""
print("hello world")
# Out:
# hello world

# %%
a=2000
b=200
print(a+b)
# Out:
# 2200

# %%
a=int(input("enter first no.:-"))
b=int(input("enter second no.:-"))
print("the sum of",a,"and",b,"is",a+b)
# Out:
# enter first no.:-10
# enter second no.:-345
# the sum of 10 and 345 is 355

# %%
a=20
b=30
print(a<b)
# Out:
# True

# %%
a=5
area=("area:-",a*a)
peremeter=("peremeter:-",a*4)
print(area,peremeter)
print(area<peremeter)
# Out:
# ('area:-', 25) ('peremeter:-', 20)
# True
